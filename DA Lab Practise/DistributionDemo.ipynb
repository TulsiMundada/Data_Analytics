# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import os

# Read the dataset
data = pd.read_csv("diabetes.csv")

# Extract the BloodPressure column into a new series
blood_pressure_series = data['BloodPressure']
print(blood_pressure_series.head())

# save the dataframe for offline viewing
if os.path.exists("deletethis-1.csv"):
    os.remove("deletethis-1.csv")  # Remove the file if it exists

data.to_csv("deletethis-1.csv", index=False)

# Calculate mean and standard deviation
mu, std = blood_pressure_series.mean(), blood_pressure_series.std()

# Calculate z-score for each value
z_scores = (blood_pressure_series - mu) / std

# Plot normal distribution graph of BloodPressure
plt.figure(figsize=(12, 6))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(blood_pressure_series, bins=20, density=True, alpha=0.6, color='b', edgecolor='black')

# Fit a normal distribution to the data
x = np.linspace(blood_pressure_series.min(), blood_pressure_series.max(), 100)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('Blood Pressure')
plt.ylabel('Density')
plt.grid(True)

# QQ Plot
plt.subplot(1, 2, 2)
stats.probplot(blood_pressure_series, dist="norm", plot=plt)
plt.title('QQ Plot')

plt.tight_layout()
plt.show()

# Plot graph showing mean +- 3 SD
plt.figure(figsize=(10, 6))
plt.hist(blood_pressure_series, bins=20, density=True, alpha=0.6, color='b', edgecolor='black')

# Fit a normal distribution to the data
x = np.linspace(blood_pressure_series.min(), blood_pressure_series.max(), 1000)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('Blood Pressure')
plt.ylabel('Density')
plt.grid(True)

# Plot mean +- 3 SD
for i in range(1, 4):
    plt.axvline(mu - i*std, color='r', linestyle='--', linewidth=2, label=f'Mean - {i} SD')
    plt.axvline(mu + i*std, color='r', linestyle='--', linewidth=2)

plt.legend()
plt.show()

# Check if mean +- 1SD, mean +- 2SD, and mean +- 3SD satisfy the empirical rule
within_1sd = (z_scores <= 1) & (z_scores >= -1)
within_2sd = (z_scores <= 2) & (z_scores >= -2)
within_3sd = (z_scores <= 3) & (z_scores >= -3)

percentage_within_1sd = np.sum(within_1sd) / len(blood_pressure_series) * 100
percentage_within_2sd = np.sum(within_2sd) / len(blood_pressure_series) * 100
percentage_within_3sd = np.sum(within_3sd) / len(blood_pressure_series) * 100

print(f"Percentage of data within mean ± 1 SD: {percentage_within_1sd:.2f}%")
print(f"Percentage of data within mean ± 2 SD: {percentage_within_2sd:.2f}%")
print(f"Percentage of data within mean ± 3 SD: {percentage_within_3sd:.2f}%")

# Create DataFrame to store BloodPressure, z-score, and within_1sd, within_2sd, within_3sd flags
result_df = pd.DataFrame({
    'BloodPressure': blood_pressure_series,
    'z_score': z_scores,
    'within_1sd': within_1sd,
    'within_2sd': within_2sd,
    'within_3sd': within_3sd
})

print(result_df.head())

if os.path.exists("deletethis-2.csv"):
    os.remove("deletethis-2.csv")  # Remove the file if it exists

result_df.to_csv("deletethis-2.csv", index=False)

# Outlier z-score box plot
plt.figure(figsize=(8, 6))
plt.boxplot(result_df['z_score'], vert=False, flierprops=dict(marker='*', markerfacecolor='red', markersize=10))
plt.xlabel('Z-score')
plt.title('Boxplot of Z-scores')
plt.grid(True)
plt.show()
# Out:
# 0    72
# 1    66
# 2    64
# 3    66
# 4    40
# Name: BloodPressure, dtype: int64
# Percentage of data within mean ± 1 SD: 85.55%
# Percentage of data within mean ± 2 SD: 94.14%
# Percentage of data within mean ± 3 SD: 95.44%
#    BloodPressure   z_score  within_1sd  within_2sd  within_3sd
# 0             72  0.149543        True        True        True
# 1             66 -0.160441        True        True        True
# 2             64 -0.263769        True        True        True
# 3             66 -0.160441        True        True        True
# 4             40 -1.503707       False        True        True

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import os

# Read the dataset
data = pd.read_csv("tips.csv")

# Extract the BloodPressure column into a new series
tip = data['tip']
print(blood_pressure_series.head())

# save the dataframe for offline viewing
if os.path.exists("deletethis-1.csv"):
    os.remove("deletethis-1.csv")  # Remove the file if it exists

data.to_csv("deletethis-1.csv", index=False)

# Calculate mean and standard deviation
mu, std = tip.mean(), tip.std()

# Calculate z-score for each value
z_scores = (tip - mu) / std

# Plot normal distribution graph of BloodPressure
plt.figure(figsize=(12, 6))

# Histogram
plt.subplot(1, 2, 1)
plt.hist(tip, bins=20, density=True, alpha=0.6, color='b', edgecolor='black')

# Fit a normal distribution to the data
x = np.linspace(blood_pressure_series.min(), blood_pressure_series.max(), 100)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('Blood Pressure')
plt.ylabel('Density')
plt.grid(True)

# QQ Plot
plt.subplot(1, 2, 2)
stats.probplot(tip, dist="norm", plot=plt)
plt.title('QQ Plot')

plt.tight_layout()
plt.show()

# Plot graph showing mean +- 3 SD
plt.figure(figsize=(10, 6))
plt.hist(tip, bins=20, density=True, alpha=0.6, color='b', edgecolor='black')

# Fit a normal distribution to the data
x = np.linspace(tip.min(), tip.max(), 1000)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('tip')
plt.ylabel('Density')
plt.grid(True)
# Plot mean +- 3 SD
for i in range(1, 4):
    plt.axvline(mu - i*std, color='r', linestyle='--', linewidth=2, label=f'Mean - {i} SD')
    plt.axvline(mu + i*std, color='r', linestyle='--', linewidth=2)

plt.legend()
plt.show()


# Fit a normal distribution to the data
x = np.linspace(data['total_bill'].min(), data['total_bill'].max(), 1000)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('total bill')
plt.ylabel('Density')
plt.grid(True)
# Plot mean +- 3 SD
for i in range(1, 4):
    plt.axvline(mu - i*std, color='r', linestyle='--', linewidth=2, label=f'Mean - {i} SD')
    plt.axvline(mu + i*std, color='r', linestyle='--', linewidth=2)

plt.legend()
plt.show()


# Fit a normal distribution to the data
x = np.linspace(data['price_per_person'].min(), data['price_per_person'].max(), 1000)
p = stats.norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)
title = "Fit results: mu = %.2f,  std = %.2f" % (mu, std)
plt.title(title)
plt.xlabel('price per person')
plt.ylabel('Density')
plt.grid(True)

# Plot mean +- 3 SD
for i in range(1, 4):
    plt.axvline(mu - i*std, color='r', linestyle='--', linewidth=2, label=f'Mean - {i} SD')
    plt.axvline(mu + i*std, color='r', linestyle='--', linewidth=2)

plt.legend()
plt.show()

# Check if mean +- 1SD, mean +- 2SD, and mean +- 3SD satisfy the empirical rule
within_1sd = (z_scores <= 1) & (z_scores >= -1)
within_2sd = (z_scores <= 2) & (z_scores >= -2)
within_3sd = (z_scores <= 3) & (z_scores >= -3)

percentage_within_1sd = np.sum(within_1sd) / len(tip) * 100
percentage_within_2sd = np.sum(within_2sd) / len(tip) * 100
percentage_within_3sd = np.sum(within_3sd) / len(tip) * 100

print(f"Percentage of data within mean ± 1 SD: {percentage_within_1sd:.2f}%")
print(f"Percentage of data within mean ± 2 SD: {percentage_within_2sd:.2f}%")
print(f"Percentage of data within mean ± 3 SD: {percentage_within_3sd:.2f}%")

# Create DataFrame to store BloodPressure, z-score, and within_1sd, within_2sd, within_3sd flags
result_df = pd.DataFrame({
    'tip': tip,
    'z_score': z_scores,
    'within_1sd': within_1sd,
    'within_2sd': within_2sd,
    'within_3sd': within_3sd
})

print(result_df.head())

if os.path.exists("deletethis-2.csv"):
    os.remove("deletethis-2.csv")  # Remove the file if it exists

result_df.to_csv("deletethis-2.csv", index=False)

# Outlier z-score box plot
plt.figure(figsize=(8, 6))
plt.boxplot(result_df['z_score'], vert=False, flierprops=dict(marker='*', markerfacecolor='red', markersize=10))
plt.xlabel('Z-score')
plt.title('Boxplot of Z-scores')
plt.grid(True)
plt.show()
# Out:
# 0    72
# 1    66
# 2    64
# 3    66
# 4    40
# Name: BloodPressure, dtype: int64
# Percentage of data within mean ± 1 SD: 74.59%
# Percentage of data within mean ± 2 SD: 95.90%
# Percentage of data within mean ± 3 SD: 98.77%
#     tip   z_score  within_1sd  within_2sd  within_3sd
# 0  1.01 -1.436993       False        True        True
# 1  1.66 -0.967217        True        True        True
# 2  3.50  0.362610        True        True        True
# 3  3.31  0.225291        True        True        True
# 4  3.61  0.442111        True        True        True

# %%
from sklearn.datasets import fetch_california_housing
housing,target = fetch_california_housing(as_frame = True,return_X_y=True)

# %%
print(housing.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
print(target.head())
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
# correlation of all the column with each other
print(housing.corr())
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc     -0.079809  -0.015176
# HouseAge    0.011173  -0.108197
# AveRooms    0.106389  -0.027540
# AveBedrms   0.069721   0.013344
# Population -0.108785   0.099773
# AveOccup    0.002366   0.002476
# Latitude    1.000000  -0.924664
# Longitude  -0.924664   1.000000

# %%
# correlation of two specific column
corr = housing.corr()
print(corr['MedInc']['AveRooms'])
# Out:
# 0.32689543164129786

# %%
#visual view
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cmap =  sns.diverging_palette(300,100, as_cmap=True)
sns.heatmap(corr,vmin = -1.0,vmax=1.0,square=True,cmap=cmap)
plt.show()

# %%
data = pd.read_csv('StudentsPerformance.csv')
print(data)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
correlation_cofficient = data['reading score'].corr(data['writing score'])
print(f"correlation cofficient : {correlation_cofficient}")
plt.scatter(x="reading score",y="writing score",data=data)
plt.xlabel("Reading Score")
plt.xlabel("Writing Score")
plt.title(f"Scatter plot (Corrilation {correlation_cofficient})")
residule = data["writing score"] - data["reading score"]
print(residule)
std_residule = residule.std()
outlier = data[abs(residule) > 2 * std_residule]
plt.scatter(outlier["reading score"],outlier["writing score"],color = "red",label = "Outliers")
plt.legend()
plt.show()
# Out:
# correlation cofficient : 0.9545980771462478
# 0       2
# 1      -2
# 2      -2
# 3     -13
# 4      -3
#        ..
# 995    -4
# 996     0
# 997    -6
# 998    -1
# 999     0
# Length: 1000, dtype: int64
